# %%
import pandas as pd

# %%
DF = pd.DataFrame

# %%
print(DF)
# Out:
#    Ejem1  Ejem2  Ejem3
# 0  Ejem1  Ejem2  Ejem3
# 1  Ejem1  Ejem2  Ejem3
# 2  Ejem1  Ejem2  Ejem3

# %%
DF = pd.read_json('datajson.json')

# %%
DF = pd.read_csv('datacsv.csv')

# %%
DF = pd.read_excel('dataxlsx.xlsx')

# %%
DF.to_json('Datos exportados.json')
