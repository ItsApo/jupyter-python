# %% [markdown]
# Se importa pandas

# %%
import pandas as pd

# %% [markdown]
# Aqui creo 3 dataframes que es donde voy a importar cada uno de los datos de ada tipo de archivo

# %%
DFjson = pd.DataFrame

# %%
DFcsv = pd.DataFrame

# %%
DFxlsx = pd.DataFrame

# %% [markdown]
# Aqui imprimo los 3 dataframes

# %%
print(DFjson)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(DFcsv)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(DFxlsx)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# Aqui leo los archivos y los importo a cada dataframe

# %%
DFjson = pd.read_json('import.json')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-d26551d81497> in <cell line: 1>()
# ----> 1 DFjson = pd.read_json('import.json')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
DFcsv = pd.read_csv('importar.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-fd3b052c4135> in <cell line: 1>()
# ----> 1 DFcsv = pd.read_csv('importar.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
DFxlsx = pd.read_excel('importeu.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-d836979d2fa2> in <cell line: 1>()
# ----> 1 DFxlsx = pd.read_excel('importeu.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %% [markdown]
# Este CombinedDataFrame sirve para combinar los 3 dataframes que cree y que se genere uno solo con todos los datos de todos los archivos

# %%
CombinedDataFrame = pd.concat([DFjson, DFcsv, DFxlsx])

# %% [markdown]
# Aqui imprimo el dataframe que contiene los datos de los 3 archivos (o 3 dataframes)

# %%
print(CombinedDataFrame)
# Out:
#      Nombre   Apellido  Edad
# 0  Giovanni     Alzate   789
# 1     Tilin    Agudelo    25
# 2      Otro    Usuario    30
# 0      Pepe      Chino    12
# 1   Ejemplo    Ejemplo    90
# 2     Cesar     Sotelo    50
# 0     Laura     Ocampo    15
# 1    Checho      Muñoz    19
# 2      Sara  nfetamina    18

# %% [markdown]
# Y aqui por ultimo exporto los datos en un archivo JSON para que queden guardados en los archivos listo para descargarse

# %%
CombinedDataFrame.to_json('ExportData.json', orient='records', lines=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-3dd639a92574> in <cell line: 1>()
# ----> 1 CombinedDataFrame.to_json('ExportData.json', orient='records', lines=True)
#
# NameError: name 'CombinedDataFrame' is not defined
